# %%
import pandas as pd
import os

# %%
df = pd.read_csv("Sales_April_2019.csv")
files =  os.listdir('./Sales_Data')
print(files)
all_month_data = pd.DataFrame()
for file in files:
    df = pd.read_csv(("./Sales_Data/"+file))
    all_month_data = pd.concat([all_month_data, df])

    all_month_data.to_csv("all_data.csv", index=False)

    all_month_data.head()
# Out:
# ['Sales_May_2019.csv', 'Sales_March_2019.csv', 'Sales_February_2019.csv', 'Sales_June_2019.csv', 'Sales_January_2019.csv', 'Sales_July_2019.csv', 'Sales_December_2019.csv', 'Sales_September_2019.csv', 'Sales_August_2019.csv', 'Sales_October_2019.csv', 'Sales_November_2019.csv']

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1      150.0
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101

# %%
all_data['Month'] = 3
all_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address  Month
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001      3
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001      3
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001      3
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001      3
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101      3

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]

all_data.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   194095        Wired Headphones                1      11.99
# 1   194096   AA Batteries (4-pack)                1       3.84
# 2   194097        27in FHD Monitor                1     149.99
# 3   194098        Wired Headphones                1      11.99
# 4   194099  AAA Batteries (4-pack)                2       2.99
#
#        Order Date                         Purchase Address Month
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001    05
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001    05
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001    05
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001    05
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101    05

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
all_data = all_data.dropna(how='all')
all_data.head(77)
# Out:
#    Order ID                 Product Quantity Ordered Price Each  \
# 0    194095        Wired Headphones                1      11.99
# 1    194096   AA Batteries (4-pack)                1       3.84
# 2    194097        27in FHD Monitor                1     149.99
# 3    194098        Wired Headphones                1      11.99
# 4    194099  AAA Batteries (4-pack)                2       2.99
# ..      ...                     ...              ...        ...
# 73   194166      Macbook Pro Laptop                1       1700
# 74   194167   AA Batteries (4-pack)                1       3.84
# 75   194168    USB-C Charging Cable                2      11.95
# 76   194169    USB-C Charging Cable                1      11.95
# 77   194170            Google Phone                1        600
#
#         Order Date                         Purchase Address Month
# 0   05/16/19 17:14      669 2nd St, New York City, NY 10001    05
# 1   05/19/19 14:43          844 Walnut St, Dallas, TX 75001    05
# 2   05/24/19 11:36  164 Madison St, New York City, NY 10001    05
# 3   05/02/19 20:40          622 Meadow St, Dallas, TX 75001    05
# 4   05/11/19 22:55          17 Church St, Seattle, WA 98101    05
# ..             ...                                      ...   ...
# 73  05/06/19 13:30    435 North St, San Francisco, CA 94016    05
# 74  05/24/19 22:36  187 Dogwood St, San Francisco, CA 94016    05
# 75  05/20/19 13:16          583 12th St, Portland, OR 97035    05
# 76  05/01/19 18:01            49 Lake St, Atlanta, GA 30301    05
# 77  05/30/19 12:30    711 Maple St, San Francisco, CA 94016    05
#
# [77 rows x 7 columns]

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!= 'Or']

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#        Order Date                         Purchase Address  Month
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001      5
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001      5
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001      5
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001      5
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101      5

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#        Order Date                         Purchase Address  Month
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001      5
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001      5
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001      5
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001      5
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101      5

# %%
all_data['Month2'] = pd.to_datetime(all_data['Order Date']).dt.month
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#        Order Date                         Purchase Address  Month  Month2
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001      5       5
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001      5       5
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001      5       5
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001      5       5
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101      5       5

# %%
def get_city(adress):
    return adress.split(',')[1].strip(" ")
def get_state(adress):
    return adress.split(',')[2].split(" ")[1]

all_data["city"] = all_data["Purchase Address"].apply(lambda x: f"{(get_city(x))} ({get_state(x)})" )

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.groupby(['Month']).sum()
# Out:
# /tmp/ipykernel_2926/2666040485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby(['Month']).sum()
#        Quantity Ordered  Price Each  Month2       Sales
# Month
# 1                 10903  1811768.38    9709  1822256.73
# 2                 13449  2188884.72   23950  2202022.42
# 3                 17005  2791207.83   45459  2807100.38
# 4                    19     5167.43      72     5170.42
# 5                 18638  3124569.68   82690  3142047.46
# 6                 15253  2562025.61   81324  2577802.26
# 7                 16072  2632539.56  100051  2647775.76
# 8                 13448  2230345.42   95688  2244467.88
# 9                 13109  2084992.09  104589  2097560.13
# 10                22703  3715554.83  202820  3736726.88
# 11                19798  3180600.68  193303  3199603.20
# 12                28114  4588415.41  299808  4613443.34

# %%
import matplotlib.pyplot as plt

months = range(1, 13)
print(months)

plt.bar(months, all_data.groupby(['Month']).sum()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month Number')
plt.show()
# Out:
# /tmp/ipykernel_2926/3890658896.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(months, all_data.groupby(['Month']).sum()['Sales'])
# range(1, 13)

# %%
all_data.groupby(['city']).sum()
# Out:
# /tmp/ipykernel_2926/577948779.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby(['city']).sum()
#                     Quantity Ordered  Price Each   Month  Month2       Sales
# city
# Atlanta (GA)                   14969  2497028.32   98905   98905  2511043.66
# Austin (TX)                    10061  1638385.96   65937   65937  1646898.16
# Boston (MA)                    20338  3285667.02  133434  133434  3307761.85
# Dallas (TX)                    15211  2500938.78   99218   99218  2515134.93
# Los Angeles (CA)               29890  4873444.21  196218  196218  4901171.73
# New York City (NY)             25191  4192978.15  166004  166004  4217729.65
# Portland (ME)                   2485   404818.96   16172   16172   407221.78
# Portland (OR)                  10169  1662835.59   66643   66643  1672140.72
# San Francisco (CA)             45252  7401123.43  297760  297760  7445129.14
# Seattle (WA)                   14945  2458851.22   99172   99172  2471745.24

# %%
keys = [city for city, df in all_data.groupby(['city'])]

plt.bar(keys, all_data.groupby(['city']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month Number')
plt.xticks(keys, rotation='vertical', size= 8)
plt.show()
# Out:
# /tmp/ipykernel_2926/4002308051.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   keys = [city for city, df in all_data.groupby(['city'])]
# /tmp/ipykernel_2926/4002308051.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.bar(keys, all_data.groupby(['city']).sum()['Sales'])

# %%
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   194095        Wired Headphones                 1       11.99
# 1   194096   AA Batteries (4-pack)                 1        3.84
# 2   194097        27in FHD Monitor                 1      149.99
# 3   194098        Wired Headphones                 1       11.99
# 4   194099  AAA Batteries (4-pack)                 2        2.99
#
#        Order Date                         Purchase Address  Month  Month2  \
# 0  05/16/19 17:14      669 2nd St, New York City, NY 10001      5       5
# 1  05/19/19 14:43          844 Walnut St, Dallas, TX 75001      5       5
# 2  05/24/19 11:36  164 Madison St, New York City, NY 10001      5       5
# 3  05/02/19 20:40          622 Meadow St, Dallas, TX 75001      5       5
# 4  05/11/19 22:55          17 Church St, Seattle, WA 98101      5       5
#
#                  city   Sales  Hour  Minute  Count
# 0  New York City (NY)   11.99    17      14      1
# 1         Dallas (TX)    3.84    14      43      1
# 2  New York City (NY)  149.99    11      36      1
# 3         Dallas (TX)   11.99    20      40      1
# 4        Seattle (WA)    5.98    22      55      1

# %%
keys = [pair for pair, df in all_data.groupby(['Hour'])]

plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
plt-xticks(keys)
plt.grid()
plt.show
# Out:
# /tmp/ipykernel_2926/3162854262.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   keys = [pair for pair, df in all_data.groupby(['Hour'])]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [315], line 4
#       1 keys = [pair for pair, df in all_data.groupby(['Hour'])]
#       3 plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
# ----> 4 plt-xticks(keys)
#       5 plt.grid()
#       6 plt.show
#
# NameError: name 'xticks' is not defined
